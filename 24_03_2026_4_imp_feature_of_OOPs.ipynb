# %% [markdown]
# <a href="https://colab.research.google.com/github/007arjungangwar/Programming-in-Python-Section2/blob/main/24_03_2026_4_imp_feature_of_OOPs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Note**

# %%
print(isinstance(2,int))
print(isinstance("Arjun",str))
print(isinstance(2,(int,float)))
print(isinstance("Arjun",(int,float)))
print(isinstance("Arjun",(int,float,str)))
# Out:
# True
# True
# True
# False
# True

# %%
f"{9.19999:.2f}"
# Out:
# '9.20'

# %%
round(9.19999,2)
# Out:
# 9.2

# %% [markdown]
# # **4 feature of oops**

# %%
# 4 feature of oops
"""
1. Abstraction - hiding unnecessary detail from user by method or Class
2. Encapsulation - Restrict access of certain attribute or methods to protect data and enforce controlled access (Data Protection) private
3. Inheritance - Reuse the property or method from the parent class
4. Polymorphism -  Allow method in different classes to have same name but different behaviour According to object Referred to class.
"""

# %% [markdown]
# ## **Abstraction - hiding information by function(method or class)**

# %%
# Abstraction - hiding information by function(method or class)

class Student:
    def __init__(self,name, grade, percentage):
        self.name=name
        self.grade=grade
        self.percentage=percentage

    def student_info(self):
        return f"{self.name} is in {self.grade} grade and percentage is {round((self.percentage+5)/1.1,2)}%"

    # hiding info how pecentage is calculating

s2=Student("Roshni",12,92)
s2.student_info()
# Out:
# 'Roshni is in 12 grade and percentage is 88.18%'

# %% [markdown]
# **Here we are just showing the percentage to the user Not telling how we are calculating So actually by the method we are hiding the process.**

# %% [markdown]
# ## **Encapsulation: - restrict access of some attribute or method**

# %%
# Encapsulation: - restrict access of some attribute or method

class Student:
    def __init__(self,name, grade, percentage):
        self.name=name
        self.grade=grade
        self.__percentage=percentage

    def get_percentage(self):
        return self.__percentage

    def set_percentage(self,temp): # Instead of temp you can pass any of the name
        if 0<=temp<=100:
            self.__percentage=temp
            return self.__percentage
        else:
            return ("Not Allowed")


    def student_info(self):
        return f"{self.name} is in {self.grade} grade and percentage is {self.get_percentage()}%"

# %%
s1=Student("Meera",11,52)
print(s1.name,s1.grade,s1.get_percentage())
# Out:
# Meera 11 52

# %%
print(s1.name)
print(s1.grade)
# Out:
# Meera
# 11

# %%
s1.percentage
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_167/3218946610.py in <cell line: 0>()
# ----> 1 s1.percentage
#
# AttributeError: 'Student' object has no attribute 'percentage'

# %% [markdown]
# **By the double underscore(__) we are hiding, Which we don't want to show the user, Basically user can not modify those things Directly**

# %%
s1.get_percentage()
# Out:
# 52

# %%
s1.set_percentage(92)
# Out:
# 92

# %%
s1.get_percentage()
# Out:
# 92

# %%
print(s1.set_percentage(-1))
print(s1.student_info())
# Out:
# Not Allowed
# Meera is in 11 grade and percentage is 92%

# %%
s1.__dict__
# Out:
# {'name': 'Meera', 'grade': 11, '_Student__percentage': 92}

# %% [markdown]
# ## **Inheritance - inherit property of class by super**

# %%
# Inheritance - inherit property of class by super

class Student:
    def __init__(self,name, grade, percentage):
        self.name=name
        self.grade=grade
        self.percentage=percentage

    def student_info(self):
        return f"{self.name} is in {self.grade} grade and percentage is {round((self.percentage+5)/1.1,2)}%"


class GraduateStudent(Student):
    def __init__(self, name, grade, percentage, subject, marks, section, stream):
        super().__init__(name,grade,percentage)
        self.marks=marks
        self.section=section
        self.stream=stream
        self.subject=subject
        super().student_info()

# %%
s1=GraduateStudent("Nitish",12,55,["Maths", "English", "Computer"],[95,92,95] ,"section2","PCM")
s2=GraduateStudent("Advika",11,98,["Maths", "English", "Bio"],[90,97,82] ,"section2","PCB")

# %%
print(s1.subject)
print(s1.marks)
print(s1.grade)
print(s1.student_info())
# Out:
# ['Maths', 'English', 'Computer']
# [95, 92, 95]
# 12
# Nitish is in 12 grade and percentage is 54.55%

# %%
print(s2.subject)
print(s2.marks)
print(s2.grade)
print(s2.student_info())
# Out:
# ['Maths', 'English', 'Bio']
# [90, 97, 82]
# 11
# Advika is in 11 grade and percentage is 93.64%

# %% [markdown]
# ## **Polymorphism : same method name but working is different**

# %%
# Polymorphism : same method name but working is different

class Student:
    def __init__(self,name, grade, percentage):
        self.name=name
        self.grade=grade
        self.percentage=percentage

    def student_info(self):
        return f"{self.name} is in {self.grade} grade and percentage is {round((self.percentage+5)/1.1,2)}%"


class GraduateStudent(Student):
    def __init__(self, name, grade, percentage, subject, marks, section, stream):
        super().__init__(name,grade,percentage)
        self.marks=marks
        self.section=section
        self.stream=stream
        self.subject=subject
        super().student_info()

    def student_info(self):
        return f"{self.name} was in Section {self.section} had subjects {self.subject[0], self.subject[1], self.subject[2]} and stream was {self.stream} pass out from the ABC Internetional with percentage {self.percentage}"

# %%
s1=GraduateStudent("Meera",12,55,["Maths", "English", "Computer"],[95,92,95] ,"section2","PCM")
s2=GraduateStudent("Advika",11,98,["Maths", "English", "Bio"],[90,97,82] ,"section2","PCB")
s3=Student("Jessika",9,94)

# %%
print(s1.name)
print(s1.subject)
print(s1.marks)
print(s1.grade)
print(s1.student_info())
# Out:
# Meera
# ['Maths', 'English', 'Computer']
# [95, 92, 95]
# 12
# Meera was in Section section2 had subjects ('Maths', 'English', 'Computer') and stream was PCM pass out from the ABC Internetional with percentage 55

# %%
print(s2.name)
print(s2.subject)
print(s2.marks)
print(s2.grade)
print(s2.student_info())
# Out:
# Advika
# ['Maths', 'English', 'Bio']
# [90, 97, 82]
# 11
# Advika was in Section section2 had subjects ('Maths', 'English', 'Bio') and stream was PCB pass out from the ABC Internetional with percentage 98

# %%
print(s3.name)
print(s3.grade)
print(s3.percentage)
print(s3.student_info())
# Out:
# Jessika
# 9
# 94
# Jessika is in 9 grade and percentage is 90.0%

# %% [markdown]
# ## **HW. Question.**
#
#
# ```
# Check Parallel Lines
# Create a method to:
# 1)Check if two lines are parallel
#
# Condition:
# a1/b1 = a2/b2
# ```

# %%
class Line:
    def __init__(self,a,b,c):
        self.a=a
        self.b=b
        self.c=c

    def __str__(self):
        return f"{self.a}x+{self.b}y+{self.c}=0"

    def prallel_line(self,other):
        lhl=self.a/self.b
        rhl=other.a/other.b
        if lhl==rhl:
            return f"Lines {self.a}x+{self.b}y+{self.c}=0 and {other.a}x+{other.b}y+{other.c}=0 are parallel to each other."
        else:
            return f"Lines {self.a}x+{self.b}y+{self.c}=0 and {other.a}x+{other.b}y+{other.c}=0 are not parallel."

# %%
l1=Line(1,2,3)
print(l1)

l2=Line(2,2,1)
print(l2)
# Out:
# 1x+2y+3=0
# 2x+2y+1=0

# %%
print(l1.prallel_line(Line(2,2,1)))
print(l1.prallel_line(l2))
print(l2.prallel_line(l1))
# Out:
# Lines 1x+2y+3=0 and 2x+2y+1=0 are not parallel.
# Lines 1x+2y+3=0 and 2x+2y+1=0 are not parallel.
# Lines 2x+2y+1=0 and 1x+2y+3=0 are not parallel.

# %% [markdown]
# # **Detail overview about 4 imp feature of OOPs**

# %%
# 4 feature of oops
"""
1. Abstraction - hiding unnecessary detail from user by method or Class
2. Encapsulation - Restrict access of certain attribute or methods to protect data and enforce controlled access (Data Protection) private
3. Inheritance - Reuse the property or method from the parent class
4. Polymorphism -  Allow method in different classes to have same name but different behaviour According to object Referred to class.
"""

# %% [markdown]
# ## **Inheritance = Child class gets properties and methods from parent class.**

# %% [markdown]
# **Creating parents class without constructor**

# %%
class Animal:
                                        # Parent class
    def eat(self):
        print("Eating")

    def sleep(self):
        print("Sleeping")

# %%
obj1=Animal()
obj1.eat()
obj1.sleep()
# Out:
# Eating
# Sleeping

# %%
obj1=Animal()
print(obj1.eat())
print(obj1.sleep())
# Out:
# Eating
# None
# Sleeping
# None

# %% [markdown]
# **Creating parents class with constructor**

# %%
class Animal:
    def __init__(self,name):
        self.name=name
                    # Parent class
    def eat(self):
        print("Eating")

    def sleep(self):
        print("Sleeping")

# %%
ob1=Animal("Dog")
print(ob1.name)
ob1.sleep()
# Out:
# Dog
# Sleeping

# %%
ob2=Animal("Puppy")
print(ob2.name)
ob2.sleep()
# Out:
# Puppy
# Sleeping

# %% [markdown]
# **Inherit parents class without having the constructor Child also does not have the constructor**

# %%
class Animal:                    # Parent class
    def eat(self):
        return ("Eating")

    def sleep(self):
        return ("Parent Sleeping")

class Dog(Animal):               # Child class
    def bark(self):
        return ("Barking")

# %%
ob3=Animal()
print(ob3.eat())
print(ob3.sleep())
# Out:
# Eating
# Parent Sleeping

# %%
print(ob3.bark())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_10228/1504724271.py in <cell line: 0>()
# ----> 1 print(ob3.bark())
#
# AttributeError: 'Animal' object has no attribute 'bark'

# %%
d1=Dog()
print(d1.eat())
print(d1.sleep())
print(d1.bark())
# Out:
# Eating
# Parent Sleeping
# Barking

# %% [markdown]
# **Inherit parents class having the constructor Child does not have the constructor**

# %%
class Animal:
    def __init__(self,name):
        self.name=name
                            # Parent class
    def eat(self):
        return ("Eating")

    def sleep(self):
        return ("Parent Sleeping")

class Dog(Animal):               # Child class
    def bark(self):
        return ("Barking")

# %%
d2=Dog()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_11258/2163387968.py in <cell line: 0>()
# ----> 1 d2=Dog()
#
# TypeError: Animal.__init__() missing 1 required positional argument: 'name'

# %%
d2=Dog("puppy")
print(d2.name)
print(d2.eat())
print(d2.sleep())
print(d2.bark())
# Out:
# puppy
# Eating
# Parent Sleeping
# Barking

# %% [markdown]
# **Inherit parents class having the constructor Child also have the constructor**

# %%
class Animal:
    def __init__(self,name):
        self.name=name
                            # Parent class
    def eat(self):
        return ("Eating")

    def sleep(self):
        return ("Parent Sleeping")

class Dog(Animal):

    def __init__(self,color):
        self.color=color             # Child class

    def bark(self):
        return ("Barking")

# %%
ob1=Animal("Dog")
print(ob1.name)
print(ob1.eat())
print(ob1.sleep())
# Out:
# Dog
# Eating
# Parent Sleeping

# %%
ob2=Animal()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_10228/1460284980.py in <cell line: 0>()
# ----> 1 ob2=Animal()
#
# TypeError: Animal.__init__() missing 1 required positional argument: 'name'

# %%
d3=Dog("white")

print(d3.color)
print(d3.eat())
print(d3.sleep())
print(d3.bark())
# Out:
# white
# Eating
# Parent Sleeping
# Barking

# %%
print(d3.name)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_10228/704517086.py in <cell line: 0>()
# ----> 1 print(d3.name)
#
# AttributeError: 'Dog' object has no attribute 'name'

# %% [markdown]
# ### **Constructor Inheritance**

# %%
class Animal:
    def __init__(self,name):
        self.name=name
                            # Parent class
    def eat(self):
        return ("Eating")

    def sleep(self):
        return ("Parent Sleeping")

class Dog(Animal):
    def __init__(self,color,name):
        super().__init__(name)
        self.color=color             # Child class

    def bark(self):
        return ("Barking")

# %%
ob1=Animal("Dog")
print(ob1.name)
print(ob1.eat())
print(ob1.sleep())
# Out:
# Dog
# Eating
# Parent Sleeping

# %%
print(ob1.bark())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_10228/3694416916.py in <cell line: 0>()
# ----> 1 print(ob1.bark())
#
# AttributeError: 'Animal' object has no attribute 'bark'

# %%
d3=Dog("white","12")
print(d3.name)
print(d3.color)
print(d3.eat())
print(d3.sleep())
print(d3.bark())
# Out:
# 12
# white
# Eating
# Parent Sleeping
# Barking

# %% [markdown]
# ## **What is Polymorphism?**
#
# ```
# Polymorphism = Same name, different behavior.
#
# 3 Types of Polymorphism
#
# 1. Method Overriding
# 2. Method Overloading (Simulated in Python)
# 3. Operator Overloading
# ```

# %% [markdown]
# ## **Type 1: Method Overriding**
#
# ```
# Child class modifies parent class method.
# ```

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def display(self):
        print(f"Name: {self.name}, Age: {self.age}")

# %%
class Student(Person):
    def __init__(self, name, age, student_id):
        super().__init__(name, age)    # Call parent constructor
        self.student_id = student_id

    def display(self):
        super().display()               # Call parent method
        print(f"Student ID: {self.student_id}")

student = Student("Arjun", 20, "S123")
student.display()
# Out:
# Name: Arjun, Age: 20
# Student ID: S123

# %%
class Animal:
    def sound(self):
        print("Animal makes sound")

class Dog(Animal):
    def sound(self):           # Overriding
        print("Dog barks")

class Cat(Animal):
    def sound(self):           # Overriding
        print("Cat meows")

animals = [Animal(), Dog(), Cat()]
for animal in animals:
    animal.sound()
# Out:
# Animal makes sound
# Dog barks
# Cat meows

# %%
class Animal:
    def sound(self):
        print("Animal makes sound")

class Dog(Animal):
    def sound(self):
        print("Woof! Woof!")

class Cat(Animal):
    def sound(self):
        print("Meow! Meow!")

class Cow(Animal):
    def sound(self):
        print("Moo! Moo!")

animals = [Animal(), Dog(), Cat(),Cow()]
for animal in animals:
    animal.sound()
# Out:
# Animal makes sound
# Woof! Woof!
# Meow! Meow!
# Moo! Moo!

# %% [markdown]
# ### **Type 2: Method Overloading (Simulated in Python)**
#
# ```
# Same method name, different parameters.
# ```

# %%
class Multiply:

    def multiply(self,a,b):
        return a*b
    def multiply(self,a,b,c):
        return a*b*c

# %%
m1=Multiply()
m1.multiply(1,2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_9397/941425400.py in <cell line: 0>()
#       1 m1=Multiply()
# ----> 2 m1.multiply(1,2)
#
# TypeError: Multiply.multiply() missing 1 required positional argument: 'c'

# %%
class Multiply:

    def multiply(self,a,b,c=1):
        return a*b*c

# %%
m1=Multiply()
m1.multiply(1,2)
# Out:
# 2

# %%
m1=Multiply()
m1.multiply(1,2,7)
# Out:
# 14

# %%
class Multiply:
    def multiply(self,*args):
        mult=1
        for i in args:
            mult*=i

        return mult

# %%
m2=Multiply()
m2.multiply(1,2,3,4)
# Out:
# 24

# %%
class Calculator:
    # Using default arguments
    def add(self, a, b=0, c=0):
        return a + b + c

    # Using *args (best way)
    def multiply(self, *numbers):
        result = 1
        for num in numbers:
            result *= num
        return result

# %%
calc = Calculator()
print(calc.add(5))          # Output: 5
print(calc.add(5, 10))      # Output: 15
print(calc.add(5, 10, 15))  # Output: 30
# Out:
# 5
# 15
# 30

# %%
print(calc.multiply(2, 3))      # Output: 6
print(calc.multiply(2, 3, 4))   # Output: 24
# Out:
# 6
# 24

# %% [markdown]
# ### **Type 3: Operator Overloading**
#
# ```
# Changing behavior of operators for user-defined classes.
# or
# Changing behavior of operators (+, −, ∗, etc.)
# ```

# %%
class Student:
    def __init__(self, name, marks):
        self.name = name
        self.marks = marks

    # Overloading + operator
    def __add__(self, other):
        return self.marks + other.marks

s1 = Student("Arjun", 85)
s2 = Student("Rahul", 70)

print(s1 + s2)        # Output: 155
# Out:
# 155

# %%
class Student:
    def __init__(self, name, marks):
        self.name = name
        self.marks = marks

    # Overloading + operator
    def __add__(self, other):
        return self.marks + other.marks

    # Overloading > operator
    def __gt__(self, other):
        return self.marks > other.marks

s1 = Student("Arjun", 85)
s2 = Student("Rahul", 70)

print(s1 + s2)        # Output: 155
print(s1 > s2)        # Output: True
# Out:
# 155
# True

# %% [markdown]
# # **What is Abstraction?**
#
# ```
# Abstraction = Hiding implementation details, showing only essential features.
#
# How to Implement Abstraction
# We use:
# • ABC (Abstract Base Class)
# • @abstractmethod decorator
# • From module: from abc import ABC, abstractmethod
# ```

# %%
from abc import ABC, abstractmethod

class Shape(ABC):                    # Abstract class
    @abstractmethod
    def area(self):                  # Abstract method
        pass                         # No implementation

# %%
class Circle(Shape):
    def area(self):                  # Must implement
        print("Area of circle")

class Rectangle(Shape):
    def area(self):                  # Must implement
        print("Area of rectangle")

# Using the classes
circle = Circle()
rectangle = Rectangle()
circle.area()        # Output: Area of circle
rectangle.area()     # Output: Area of rectangle
# Out:
# Area of circle
# Area of rectangle

# %%
from abc import ABC, abstractmethod

class Vehicle(ABC):
    def __init__(self, brand, model):
        self.brand = brand
        self.model = model

    @abstractmethod
    def start(self):
        """Every vehicle must have a start method"""
        pass

    @abstractmethod
    def stop(self):
        """Every vehicle must have a stop method"""
        pass

    @abstractmethod
    def fuel_type(self):
        """Every vehicle must specify fuel type"""
        pass

    # Concrete method (not abstract)
    def display_info(self):
        print(f"Brand: {self.brand}, Model: {self.model}")
        print(f"Fuel Type: {self.fuel_type()}")

# %%
class Car(Vehicle):
    def start(self):
        print(f"{self.brand} {self.model}: Starting engine... Vroom!")

    def stop(self):
        print(f"{self.brand} {self.model}: Stopping engine...")

    def fuel_type(self):
        return "Petrol/Diesel"

# %%
# Using the classes
car = Car("Toyota", "Camry")
car.display_info()
car.start()
car.stop()
# Out:
# Brand: Toyota, Model: Camry
# Fuel Type: Petrol/Diesel
# Toyota Camry: Starting engine... Vroom!
# Toyota Camry: Stopping engine...

# %%
class ElectricCar(Vehicle):
    def start(self):
        print(f"{self.brand} {self.model}: Starting electric motor... Silent!")

    def stop(self):
        print(f"{self.brand} {self.model}: Shutting down...")

    def fuel_type(self):
        return "Electricity"

    # Additional method specific to electric cars
    def charge_battery(self):
        print(f"{self.brand} {self.model}: Charging battery...")

# %%
electric = ElectricCar("Tesla", "Model 3")
electric.display_info()
electric.start()
electric.charge_battery()
electric.stop()
# Out:
# Brand: Tesla, Model: Model 3
# Fuel Type: Electricity
# Tesla Model 3: Starting electric motor... Silent!
# Tesla Model 3: Charging battery...
# Tesla Model 3: Shutting down...

# %% [markdown]
# # **Static Variables and Methods**
#
# ```
# What are Static Variables?
# ```
# **Static variables = Variables shared by all objects of a class.**

# %%
class Student:
    school_name = "IIT Palakkad"    # Static variable

    def __init__(self, name):
        self.name = name

s1 = Student("Arjun")
s2 = Student("Rahul")

print(s1.school_name)    # Output: IIT Palakkad
print(s2.school_name)    # Output: IIT Palakkad
# Out:
# IIT Palakkad
# IIT Palakkad

# %%
# Change static variable
Student.school_name = "IIT Madras"
print(s1.school_name)    # Output: IIT Madras
print(s2.school_name)    # Output: IIT Madras
# Out:
# IIT Madras
# IIT Madras

# %% [markdown]
# ## **What are Static Methods?**
#
# ```
# Static methods = Methods that belong to class, not object.
# ```

# %%
class Math:
    @staticmethod
    def add(a, b):
        return a + b

    @staticmethod
    def is_even(num):
        return num % 2 == 0

# Call without creating object
print(Math.add(5, 3))       # Output: 8
print(Math.is_even(4))      # Output: True
print(Math.is_even(5))      # Output: False
# Out:
# 8
# True
# False

# %%
class Student:
    school_name = "IIT Palakkad"    # Static variable

    def __init__(self, name, marks):
        self.name = name
        self.marks = marks

    def display(self):
        print(f"{self.name}: {self.marks} - {Student.school_name}")

    @staticmethod
    def is_pass(marks):
        return marks >= 40

# %%
# Using the class
s1 = Student("Arjun", 85)
s2 = Student("Rahul", 35)

s1.display()    # Output: Arjun: 85 - IIT Palakkad
s2.display()    # Output: Rahul: 35 - IIT Palakkad

print(Student.is_pass(85))    # Output: True
print(Student.is_pass(35))    # Output: False
# Out:
# Arjun: 85 - IIT Palakkad
# Rahul: 35 - IIT Palakkad
# True
# False

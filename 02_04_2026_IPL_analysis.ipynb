# %% [markdown]
# <a href="https://colab.research.google.com/github/007arjungangwar/Programming-in-Python-Section2/blob/main/02_04_2026_IPL_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **First import required library**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **Find the first two rows of the dataset**

# %%
df=pd.read_csv("matches.csv")
df.head(2)
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
#
#                    team2                  toss_winner toss_decision  \
# 0  Kolkata Knight Riders  Royal Challengers Bangalore         field
# 1    Chennai Super Kings          Chennai Super Kings           bat
#
#                   winner result  result_margin  target_runs  target_overs  \
# 0  Kolkata Knight Riders   runs          140.0        223.0          20.0
# 1    Chennai Super Kings   runs           33.0        241.0          20.0
#
#   super_over method    umpire1      umpire2
# 0          N    NaN  Asad Rauf  RE Koertzen
# ...

# %% [markdown]
# **Find bottom two rows of the dataset**

# %%
df.tail(2)
# Out:
#            id season     city        date   match_type player_of_match  \
# 1093  1426311   2024  Chennai  2024-05-24  Qualifier 2   Shahbaz Ahmed
# 1094  1426312   2024  Chennai  2024-05-26        Final        MA Starc
#
#                                          venue                team1  \
# 1093  MA Chidambaram Stadium, Chepauk, Chennai  Sunrisers Hyderabad
# 1094  MA Chidambaram Stadium, Chepauk, Chennai  Sunrisers Hyderabad
#
#                       team2          toss_winner toss_decision  \
# 1093       Rajasthan Royals     Rajasthan Royals         field
# 1094  Kolkata Knight Riders  Sunrisers Hyderabad           bat
#
#                      winner   result  result_margin  target_runs  \
# 1093    Sunrisers Hyderabad     runs           36.0        176.0
# 1094  Kolkata Knight Riders  wickets            8.0        114.0
#
#       target_overs super_over method        umpire1      umpire2
# 1093          20.0          N    NaN    Nitin Menon    VK Sharma
# ...

# %%
df.shape
# Out:
# (1095, 20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1095 entries, 0 to 1094
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               1095 non-null   int64
#  1   season           1095 non-null   object
#  2   city             1044 non-null   object
#  3   date             1095 non-null   object
#  4   match_type       1095 non-null   object
#  5   player_of_match  1090 non-null   object
#  6   venue            1095 non-null   object
#  7   team1            1095 non-null   object
#  8   team2            1095 non-null   object
#  9   toss_winner      1095 non-null   object
#  10  toss_decision    1095 non-null   object
#  11  winner           1090 non-null   object
#  12  result           1095 non-null   object
#  13  result_margin    1076 non-null   float64
#  14  target_runs      1092 non-null   float64
#  15  target_overs     1092 non-null   float64
# ...

# %% [markdown]
# **find the name of the column present in the dataset**

# %%
df.keys()
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire1', 'umpire2'],
#       dtype='object')

# %% [markdown]
# **check the null value present in each column**

# %%
df.isnull().sum()
# Out:
# id                    0
# season                0
# city                 51
# date                  0
# match_type            0
# player_of_match       5
# venue                 0
# team1                 0
# team2                 0
# toss_winner           0
# toss_decision         0
# winner                5
# result                0
# result_margin        19
# target_runs           3
# target_overs          3
# super_over            0
# method             1074
# umpire1               0
# umpire2               0
# dtype: int64

# %% [markdown]
# **Strategy to fill null value**

# %%
# df["result_margin"].fillna(5,inplace=True)

# %%
df.isnull().sum()
# Out:
# id                    0
# season                0
# city                 51
# date                  0
# match_type            0
# player_of_match       5
# venue                 0
# team1                 0
# team2                 0
# toss_winner           0
# toss_decision         0
# winner                5
# result                0
# result_margin         0
# target_runs           3
# target_overs          3
# super_over            0
# method             1074
# umpire1               0
# umpire2               0
# dtype: int64

# %%
df.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire1', 'umpire2'],
#       dtype='object')

# %% [markdown]
# **Find the player of the match in Matches dataset**

# %%
df["player_of_match"]
# Out:
# 0           BB McCullum
# 1            MEK Hussey
# 2           MF Maharoof
# 3            MV Boucher
# 4             DJ Hussey
#              ...
# 1090    Abhishek Sharma
# 1091           MA Starc
# 1092           R Ashwin
# 1093      Shahbaz Ahmed
# 1094           MA Starc
# Name: player_of_match, Length: 1095, dtype: object

# %% [markdown]
# **Find the top five player of the match in the IPL history**

# %%
df["player_of_match"].value_counts().head()
# Out:
# player_of_match
# AB de Villiers    25
# CH Gayle          22
# RG Sharma         19
# DA Warner         18
# V Kohli           18
# Name: count, dtype: int64

# %% [markdown]
# **plot the top five player of the match in the IPL history**

# %%
df["player_of_match"].value_counts().head().plot(kind="barh",figsize=(5,2))
plt.title("Top 5 player of the match")
plt.ylabel("Players name")
plt.xlabel("Number of matches")
plt.show()

# %% [markdown]
# **Can you just tell me the decision after winning the toss What team usually choose to do.**

# %%
df["toss_decision"].value_counts()
# Out:
# toss_decision
# field    704
# bat      391
# Name: count, dtype: int64

# %%
# ! pip install matplotlib
# import matplotlib.pyplot as plt

# %%
df["toss_decision"].value_counts().plot(kind="pie",figsize=(5,3),autopct="%1.1f%%",title="Toss Decision by teams")
# Out:
# <Axes: title={'center': 'Toss Decision by teams'}, ylabel='count'>

# %%
df.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
df.head(2)
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
#
#                    team2                  toss_winner toss_decision  \
# 0  Kolkata Knight Riders  Royal Challengers Bangalore         field
# 1    Chennai Super Kings          Chennai Super Kings           bat
#
#                   winner result  result_margin  target_runs  target_overs  \
# 0  Kolkata Knight Riders   runs          140.0        223.0          20.0
# 1    Chennai Super Kings   runs           33.0        241.0          20.0
#
#   super_over method    umpire1      umpire2
# 0          N    NaN  Asad Rauf  RE Koertzen
# ...

# %% [markdown]
# **Can you just tell me top 5 cities where most of the IPL matches is conducted**

# %%
df["city"].value_counts().head()
# Out:
# city
# Mumbai       173
# Kolkata       93
# Delhi         90
# Chennai       85
# Hyderabad     77
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
df["city"].value_counts().head().plot(kind="bar",figsize=(4,3))
plt.title("Top 5 venue")
plt.xlabel("city")
plt.ylabel("number of matches")
plt.show()

# %% [markdown]
# ### **Create the pandas dataframe and series by using list and dict**

# %%
# Numeric series
s = pd.Series([2, 4, 5, 6, 9])
print(s)
# Out:
# 0    2
# 1    4
# 2    5
# 3    6
# 4    9
# dtype: int64

# %%
# Series with custom index
custom_series = pd.Series([2, 4, 5, 6, 9], index=['a', 'b', 'c','d','e'])
custom_series
# Out:
# a    2
# b    4
# c    5
# d    6
# e    9
# dtype: int64

# %%
# From list
df_sample = pd.DataFrame([[22, 42, 5, 16, 9],['a', 'b', 'c','d','e']])
df_sample
# Out:
#     0   1  2   3  4
# 0  22  42  5  16  9
# 1   a   b  c   d  e

# %%
# From list
df_sample = pd.DataFrame([[22, 42, 5, 16, 9],['a', 'b', 'c','d','e']])
df_sample.rename(columns={0:"col1",1:"col2",2:"col3",3:"col4",4:"col5"},inplace=True)
df_sample
# Out:
#   col1 col2 col3 col4 col5
# 0   22   42    5   16    9
# 1    a    b    c    d    e

# %%
# From dictionary
df_sample = pd.DataFrame({
    'name': ['Vinay', 'Kushal', 'Aman', 'Rahul'],
    'age': [22, 25, 24, 28],
    'occupation': ['engineer', 'doctor', 'data analyst', 'teacher']
})

df_sample
# Out:
#      name  age    occupation
# 0   Vinay   22      engineer
# 1  Kushal   25        doctor
# 2    Aman   24  data analyst
# 3   Rahul   28       teacher

# %%
df.head(2)
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
#
#                    team2                  toss_winner toss_decision  \
# 0  Kolkata Knight Riders  Royal Challengers Bangalore         field
# 1    Chennai Super Kings          Chennai Super Kings           bat
#
#                   winner result  result_margin  target_runs  target_overs  \
# 0  Kolkata Knight Riders   runs          140.0        223.0          20.0
# 1    Chennai Super Kings   runs           33.0        241.0          20.0
#
#   super_over method    umpire1      umpire2
# 0          N    NaN  Asad Rauf  RE Koertzen
# ...

# %% [markdown]
# **Can you just tell me how many times match gone in super over**

# %%
df["super_over"].value_counts()
# Out:
# super_over
# N    1081
# Y      14
# Name: count, dtype: int64

# %%
df["super_over"].value_counts().plot(kind="pie",figsize=(5,3),autopct="%1.2f%%")
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# **Can you just tell me About The win details in IPL History**

# %%
df["result"].value_counts()
# Out:
# result
# wickets      578
# runs         498
# tie           14
# no result      5
# Name: count, dtype: int64

# %%
df["result"].value_counts().plot(kind="barh",figsize=(5,2))
# Out:
# <Axes: ylabel='result'>

# %% [markdown]
# **Which team win most no. of the matches in IPL history**

# %%
df["winner"].value_counts().head(5)
# Out:
# winner
# Mumbai Indians                 144
# Chennai Super Kings            138
# Kolkata Knight Riders          131
# Royal Challengers Bangalore    116
# Rajasthan Royals               112
# Name: count, dtype: int64

# %%
df["winner"].value_counts().head(5).plot(kind="barh",color="skyblue",figsize=(5,2))
# Out:
# <Axes: ylabel='winner'>

# %% [markdown]
# ### **import delivery data set**

# %%
df2=pd.read_csv("deliveries.csv")
df2.head(2)
# Out:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 1    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
#
#    ball       batter   bowler  non_striker  batsman_runs  extra_runs  \
# 0     1   SC Ganguly  P Kumar  BB McCullum             0           1
# 1     2  BB McCullum  P Kumar   SC Ganguly             0           0
#
#    total_runs extras_type  is_wicket player_dismissed dismissal_kind fielder
# 0           1     legbyes          0              NaN            NaN     NaN
# 1           0         NaN          0              NaN            NaN     NaN

# %%
df2.shape
# Out:
# (260920, 17)

# %% [markdown]
# **Can you just tell me how many matches played Teams in IPL history**

# %%
df2=df["team1"].value_counts()+df["team2"].value_counts()
df2.sort_values(ascending=False)
# Out:
# Mumbai Indians                 261
# Kolkata Knight Riders          251
# Royal Challengers Bangalore    240
# Chennai Super Kings            238
# Rajasthan Royals               221
# Kings XI Punjab                190
# Sunrisers Hyderabad            182
# Delhi Daredevils               161
# Delhi Capitals                  91
# Deccan Chargers                 75
# Punjab Kings                    56
# Pune Warriors                   46
# Gujarat Titans                  45
# Lucknow Super Giants            44
# Gujarat Lions                   30
# Rising Pune Supergiant          16
# Royal Challengers Bengaluru     15
# Kochi Tuskers Kerala            14
# Rising Pune Supergiants         14
# Name: count, dtype: int64

# %%
six=df2[df2["batsman_runs"]==6]
six.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batter', 'bowler', 'non_striker', 'batsman_runs', 'extra_runs',
#        'total_runs', 'extras_type', 'is_wicket', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
six.head(2)
# Out:
#     match_id  inning           batting_team                 bowling_team  \
# 10    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 20    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
#
#     over  ball       batter     bowler non_striker  batsman_runs  extra_runs  \
# 10     1     4  BB McCullum     Z Khan  SC Ganguly             6           0
# 20     3     2  BB McCullum  AA Noffke  SC Ganguly             6           0
#
#     total_runs extras_type  is_wicket player_dismissed dismissal_kind fielder
# 10           6         NaN          0              NaN            NaN     NaN
# 20           6         NaN          0              NaN            NaN     NaN

# %% [markdown]
# **Can you just tell me the batsman name who hit the most of the sexes in IPL History**

# %%
six["batter"].value_counts().head()
# Out:
# batter
# CH Gayle          359
# RG Sharma         281
# V Kohli           273
# AB de Villiers    253
# MS Dhoni          252
# Name: count, dtype: int64

# %%
six["batter"].value_counts().head().plot(kind="pie",figsize=(4,3))
# Out:
# <Axes: ylabel='count'>

# %%
six["batter"].value_counts().head(8).plot(kind="pie",figsize=(4,3),autopct="%1.1f%%")
# Out:
# <Axes: ylabel='count'>

# %%
six["batter"].value_counts().head().plot(kind="barh",figsize=(4,3))
plt.xlabel("total number of six hit by batsman(players)")
# Out:
# Text(0.5, 0, 'total number of six hit by batsman(players)')

# %% [markdown]
# **Find the batsman name on the particular ground hit the most 6`s**

# %%
df.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batter', 'bowler', 'non_striker', 'batsman_runs', 'extra_runs',
#        'total_runs', 'extras_type', 'is_wicket', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %% [markdown]
# **First concatenate the two dataset base on the same column name**

# %% [markdown]
# **inplace equal_to true is useful so that changes will remain permanent**

# %%
df.rename(columns={"id":"match_id"},inplace=True)
df.columns
# Out:
# Index(['match_id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
df3=df.merge(df2,how="inner",on="match_id")

# %%
df3.head(2)
# Out:
#    match_id   season       city        date match_type player_of_match  \
# 0    335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 1    335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
#
#                    venue                        team1                  team2  \
# 0  M Chinnaswamy Stadium  Royal Challengers Bangalore  Kolkata Knight Riders
# 1  M Chinnaswamy Stadium  Royal Challengers Bangalore  Kolkata Knight Riders
#
#                    toss_winner  ...   bowler  non_striker batsman_runs  \
# 0  Royal Challengers Bangalore  ...  P Kumar  BB McCullum            0
# 1  Royal Challengers Bangalore  ...  P Kumar   SC Ganguly            0
#
#    extra_runs  total_runs  extras_type is_wicket player_dismissed  \
# 0           1           1      legbyes         0              NaN
# 1           0           0          NaN         0              NaN
#
#   dismissal_kind fielder
# 0            NaN     NaN
# 1            NaN     NaN
#
# ...

# %%
df3.shape
# Out:
# (260920, 36)

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260920 entries, 0 to 260919
# Data columns (total 36 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          260920 non-null  int64
#  1   season            260920 non-null  object
#  2   city              248523 non-null  object
#  3   date              260920 non-null  object
#  4   match_type        260920 non-null  object
#  5   player_of_match   260430 non-null  object
#  6   venue             260920 non-null  object
#  7   team1             260920 non-null  object
#  8   team2             260920 non-null  object
#  9   toss_winner       260920 non-null  object
#  10  toss_decision     260920 non-null  object
#  11  winner            260430 non-null  object
#  12  result            260920 non-null  object
#  13  result_margin     260920 non-null  float64
#  14  target_runs       260611 non-null  float64
#  15  target_overs      260611 non-null  float64
# ...

# %%
df3.columns
# Out:
# Index(['match_id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire1', 'umpire2', 'inning', 'batting_team',
#        'bowling_team', 'over', 'ball', 'batter', 'bowler', 'non_striker',
#        'batsman_runs', 'extra_runs', 'total_runs', 'extras_type', 'is_wicket',
#        'player_dismissed', 'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
df3.head(2)
# Out:
#    match_id   season       city        date match_type player_of_match  \
# 0    335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 1    335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
#
#                    venue                        team1                  team2  \
# 0  M Chinnaswamy Stadium  Royal Challengers Bangalore  Kolkata Knight Riders
# 1  M Chinnaswamy Stadium  Royal Challengers Bangalore  Kolkata Knight Riders
#
#                    toss_winner  ...   bowler  non_striker batsman_runs  \
# 0  Royal Challengers Bangalore  ...  P Kumar  BB McCullum            0
# 1  Royal Challengers Bangalore  ...  P Kumar   SC Ganguly            0
#
#    extra_runs  total_runs  extras_type is_wicket player_dismissed  \
# 0           1           1      legbyes         0              NaN
# 1           0           0          NaN         0              NaN
#
#   dismissal_kind fielder
# 0            NaN     NaN
# 1            NaN     NaN
#
# ...

# %% [markdown]
# Total number of ball Delivery On particular venue

# %%
df3["venue"].value_counts()
# Out:
# venue
# Eden Gardens                                                             17988
# Wankhede Stadium                                                         17591
# M Chinnaswamy Stadium                                                    14907
# Feroz Shah Kotla                                                         13950
# MA Chidambaram Stadium, Chepauk                                          11760
# Rajiv Gandhi International Stadium, Uppal                                11604
# Dubai International Cricket Stadium                                      11229
# Sawai Mansingh Stadium                                                   11150
# Wankhede Stadium, Mumbai                                                 10915
# Punjab Cricket Association Stadium, Mohali                                8266
# Sheikh Zayed Stadium                                                      6925
# MA Chidambaram Stadium, Chepauk, Chennai                                  6816
# ...

# %% [markdown]
# Find the all detail from the Particular Stadium name

# %%
Wankhede_Stadium=df3.groupby("venue").get_group("Wankhede Stadium")
Wankhede_Stadium
# Out:
#         match_id   season    city        date match_type player_of_match  \
# 692       335985  2007/08  Mumbai  2008-04-20     League      MV Boucher
# 693       335985  2007/08  Mumbai  2008-04-20     League      MV Boucher
# 694       335985  2007/08  Mumbai  2008-04-20     League      MV Boucher
# 695       335985  2007/08  Mumbai  2008-04-20     League      MV Boucher
# 696       335985  2007/08  Mumbai  2008-04-20     League      MV Boucher
# ...          ...      ...     ...         ...        ...             ...
# 178078   1178431     2019  Mumbai  2019-05-05     League       HH Pandya
# 178079   1178431     2019  Mumbai  2019-05-05     League       HH Pandya
# 178080   1178431     2019  Mumbai  2019-05-05     League       HH Pandya
# 178081   1178431     2019  Mumbai  2019-05-05     League       HH Pandya
# 178082   1178431     2019  Mumbai  2019-05-05     League       HH Pandya
#
#                    venue                  team1                        team2  \
# ...

# %%
Wankhede_Stadium.columns
# Out:
# Index(['match_id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire1', 'umpire2', 'inning', 'batting_team',
#        'bowling_team', 'over', 'ball', 'batter', 'bowler', 'non_striker',
#        'batsman_runs', 'extra_runs', 'total_runs', 'extras_type', 'is_wicket',
#        'player_dismissed', 'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
mask=(Wankhede_Stadium["batsman_runs"]==6)
mask
# Out:
# 692       False
# 693       False
# 694       False
# 695       False
# 696       False
#           ...
# 178078    False
# 178079    False
# 178080    False
# 178081    False
# 178082     True
# Name: batsman_runs, Length: 17591, dtype: bool

# %% [markdown]
# Select only those row on which Batsman hit the six only on Wankhede_Stadium

# %%
Wankhede_Stadium[mask]
# Out:
#         match_id   season    city        date match_type player_of_match  \
# 723       335985  2007/08  Mumbai  2008-04-20     League      MV Boucher
# 765       335985  2007/08  Mumbai  2008-04-20     League      MV Boucher
# 798       335985  2007/08  Mumbai  2008-04-20     League      MV Boucher
# 801       335985  2007/08  Mumbai  2008-04-20     League      MV Boucher
# 808       335985  2007/08  Mumbai  2008-04-20     League      MV Boucher
# ...          ...      ...     ...         ...        ...             ...
# 177985   1178431     2019  Mumbai  2019-05-05     League       HH Pandya
# 178005   1178431     2019  Mumbai  2019-05-05     League       HH Pandya
# 178006   1178431     2019  Mumbai  2019-05-05     League       HH Pandya
# 178065   1178431     2019  Mumbai  2019-05-05     League       HH Pandya
# 178082   1178431     2019  Mumbai  2019-05-05     League       HH Pandya
#
#                    venue                  team1                        team2  \
# ...

# %% [markdown]
# Find out the Name of the batsman who hit most of the sexes on the Wankhede_Stadium

# %%
Wankhede_Stadium[mask]["batter"].value_counts().head(10)
# Out:
# batter
# KA Pollard     84
# RG Sharma      68
# AT Rayudu      30
# HH Pandya      28
# SK Raina       25
# SR Watson      22
# JC Buttler     21
# CH Gayle       20
# LMP Simmons    18
# V Kohli        18
# Name: count, dtype: int64

# %%
Wankhede_Stadium[mask]["batter"].value_counts().head(10).plot(kind="bar",figsize=(4,3))
# Out:
# <Axes: xlabel='batter'>

# %%
Wankhede_Stadium[mask]["batter"].value_counts().head(2).plot(kind="pie",figsize=(4,3),autopct="%1.1f%%",explode=(0.05, 0))
# Out:
# <Axes: ylabel='count'>

# %%
Wankhede_Stadium[mask]["batter"].value_counts().head(2).plot(kind="pie",figsize=(4,3),autopct="%1.1f%%",explode=(0.05, 0),colors=['#ff9999', '#66b3ff'])
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# Create the function who will take stadium name And run as input from the user and Return top_10_batsman_run_in_stadium (That particular stadium)

# %%
def top_10_batsman_run_in_stadium(stadium,run):
    stadium=df3.groupby("venue").get_group(stadium)
    mask=(stadium["batsman_runs"]==run)
    stadium[mask]
    return stadium[mask]["batter"].value_counts().head(10)

top_10_batsman_run_in_stadium("Wankhede Stadium",6)
# Out:
# batter
# KA Pollard     84
# RG Sharma      68
# AT Rayudu      30
# HH Pandya      28
# SK Raina       25
# SR Watson      22
# JC Buttler     21
# CH Gayle       20
# LMP Simmons    18
# V Kohli        18
# Name: count, dtype: int64

# %%
venue_list=df3["venue"].value_counts().index.to_list()
venue_list
# Out:
# ['Eden Gardens',
#  'Wankhede Stadium',
#  'M Chinnaswamy Stadium',
#  'Feroz Shah Kotla',
#  'MA Chidambaram Stadium, Chepauk',
#  'Rajiv Gandhi International Stadium, Uppal',
#  'Dubai International Cricket Stadium',
#  'Sawai Mansingh Stadium',
#  'Wankhede Stadium, Mumbai',
#  'Punjab Cricket Association Stadium, Mohali',
#  'Sheikh Zayed Stadium',
#  'MA Chidambaram Stadium, Chepauk, Chennai',
#  'Sharjah Cricket Stadium',
#  'Narendra Modi Stadium, Ahmedabad',
#  'Maharashtra Cricket Association Stadium',
#  'Dr DY Patil Sports Academy, Mumbai',
#  'Brabourne Stadium, Mumbai',
#  'Dr DY Patil Sports Academy',
#  'Arun Jaitley Stadium, Delhi',
#  'Eden Gardens, Kolkata',
#  'Subrata Roy Sahara Stadium',
#  'Kingsmead',
#  'Rajiv Gandhi International Stadium',
#  'M.Chinnaswamy Stadium',
#  'M Chinnaswamy Stadium, Bengaluru',
#  'Arun Jaitley Stadium',
#  'Bharat Ratna Shri Atal Bihari Vajpayee Ekana Cricket Stadium, Lucknow',
# ...

# %% [markdown]
# can you give top_10_batsman_6run_in_stadium (each stadium)

# %%
for i in venue_list:
    print("venue",i,end="\n")
    print(f"{top_10_batsman_run_in_stadium(i,6)}")
# Out:
# venue Eden Gardens
# batter
# AD Russell    63
# YK Pathan     45
# CH Gayle      42
# RV Uthappa    33
# N Rana        27
# G Gambhir     26
# CA Lynn       23
# SP Narine     21
# SC Ganguly    21
# RG Sharma     18
# Name: count, dtype: int64
# venue Wankhede Stadium
# batter
# KA Pollard     84
# RG Sharma      68
# AT Rayudu      30
# HH Pandya      28
# SK Raina       25
# SR Watson      22
# JC Buttler     21
# CH Gayle       20
# LMP Simmons    18
# V Kohli        18
# Name: count, dtype: int64
# venue M Chinnaswamy Stadium
# batter
# CH Gayle          126
# AB de Villiers     82
# V Kohli            82
# Yuvraj Singh       23
# DA Warner          19
# RV Uthappa         19
# MS Dhoni           18
# MA Agarwal         16
# BB McCullum        15
# YK Pathan          14
# Name: count, dtype: int64
# venue Feroz Shah Kotla
# batter
# V Sehwag        38
# CH Gayle        23
# KD Karthik      23
# DA Warner       22
# KP Pietersen    21
# SS Iyer         18
# RR Pant         18
# ...

# %% [markdown]
# Can you create a function so that we can get Idea on particular stadium top number of Batsman make perticular runs.

# %%
def top_no_batsman_run_in_stadium(stadium,run,no):
    stadium=df3.groupby("venue").get_group(stadium)
    mask=(stadium["batsman_runs"]==run)
    stadium[mask]
    return stadium[mask]["batter"].value_counts().head(no)

top_no_batsman_run_in_stadium("Wankhede Stadium",6,2)
# Out:
# batter
# KA Pollard    84
# RG Sharma     68
# Name: count, dtype: int64

# %%
for i in venue_list:
    print("venue",i,end="\n")
    print(f"{top_no_batsman_run_in_stadium(i,4,2)}")
# Out:
# venue Eden Gardens
# batter
# G Gambhir     165
# RV Uthappa    124
# Name: count, dtype: int64
# venue Wankhede Stadium
# batter
# RG Sharma       156
# SR Tendulkar     94
# Name: count, dtype: int64
# venue M Chinnaswamy Stadium
# batter
# V Kohli     165
# CH Gayle    116
# Name: count, dtype: int64
# venue Feroz Shah Kotla
# batter
# V Sehwag     116
# G Gambhir     76
# Name: count, dtype: int64
# venue MA Chidambaram Stadium, Chepauk
# batter
# SK Raina      116
# MEK Hussey     90
# Name: count, dtype: int64
# venue Rajiv Gandhi International Stadium, Uppal
# batter
# S Dhawan     122
# DA Warner    110
# Name: count, dtype: int64
# venue Dubai International Cricket Stadium
# batter
# KL Rahul    51
# S Dhawan    46
# Name: count, dtype: int64
# venue Sawai Mansingh Stadium
# batter
# AM Rahane    127
# R Dravid      95
# Name: count, dtype: int64
# venue Wankhede Stadium, Mumbai
# batter
# SA Yadav     65
# RG Sharma    62
# Name: count, dtype: int64
# ...

# %% [markdown]
# **top 5 batsman in ipl history in term of score**

# %%
# top 5 batsman in ipl history in term of score
df2.groupby("batter")["batsman_runs"].sum().sort_values(ascending=False).head()
# Out:
# batter
# V Kohli      8014
# S Dhawan     6769
# RG Sharma    6630
# DA Warner    6567
# SK Raina     5536
# Name: batsman_runs, dtype: int64

# %% [markdown]
# **Can you please give me the bowler name who out The particular bestman "Virat Kohli" Most of the time**

# %%
# Can you please give me the bowler name who out The particular bestman "Virat Kohli" Most of the time
vk = df2[df2['batter'] == 'V Kohli']
vk.groupby('bowler')['player_dismissed'].count().sort_values(ascending=False).head(8)
# Out:
# bowler
# Sandeep Sharma    7
# A Nehra           6
# Mohammed Shami    5
# RA Jadeja         5
# UT Yadav          5
# B Kumar           5
# JJ Bumrah         5
# DS Kulkarni       4
# Name: player_dismissed, dtype: int64

# %%
vk.groupby('bowler')['player_dismissed'].count().sort_values(ascending=False).head(5).plot(kind="barh",figsize=(5,2))
plt.xlabel("Number of times out by bowler")
plt.show()

# %% [markdown]
# **Can you please give me the bowler name who out The particular bestman "Rohit sharma" Most of the time**

# %%
rs = df2[df2['batter'] == 'RG Sharma']
rs.groupby('bowler')['player_dismissed'].count().sort_values(ascending=False).head(8)
# Out:
# bowler
# SP Narine         9
# A Mishra          7
# R Vinay Kumar     6
# SK Trivedi        6
# UT Yadav          5
# DJ Bravo          5
# Sandeep Sharma    5
# Ravi Bishnoi      4
# Name: player_dismissed, dtype: int64

# %%
rs.groupby('bowler')['player_dismissed'].count().sort_values(ascending=False).head(8).plot(kind="barh",figsize=(5,2))
plt.xlabel("Number of times out by bowler")
plt.show()

# %% [markdown]
# **filter the records in delivery data set where "batsman hit sixes" In IPL history**

# %%
six=df3[df3["batsman_runs"]==6]
six.head(2)
# Out:
#     match_id   season       city        date match_type player_of_match  \
# 10    335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
# 20    335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
#
#                     venue                        team1                  team2  \
# 10  M Chinnaswamy Stadium  Royal Challengers Bangalore  Kolkata Knight Riders
# 20  M Chinnaswamy Stadium  Royal Challengers Bangalore  Kolkata Knight Riders
#
#                     toss_winner  ...     bowler non_striker batsman_runs  \
# 10  Royal Challengers Bangalore  ...     Z Khan  SC Ganguly            6
# 20  Royal Challengers Bangalore  ...  AA Noffke  SC Ganguly            6
#
#     extra_runs  total_runs  extras_type is_wicket player_dismissed  \
# 10           0           6          NaN         0              NaN
# 20           0           6          NaN         0              NaN
#
#    dismissal_kind fielder
# 10            NaN     NaN
# 20            NaN     NaN
#
# ...

# %% [markdown]
# **Who hit most number of sixes in IPL history**

# %%
six["batter"].value_counts().head(10)
# Out:
# batter
# CH Gayle          359
# RG Sharma         281
# V Kohli           273
# AB de Villiers    253
# MS Dhoni          252
# DA Warner         236
# KA Pollard        224
# AD Russell        209
# SV Samson         206
# SK Raina          204
# Name: count, dtype: int64

# %% [markdown]
# **Who hit most number of 4runs in IPL history**

# %%
four=df3[df3["batsman_runs"]==4]
four["batter"].value_counts().head(10)
# Out:
# batter
# S Dhawan        768
# V Kohli         708
# DA Warner       663
# RG Sharma       599
# SK Raina        506
# G Gambhir       492
# RV Uthappa      481
# AM Rahane       479
# KD Karthik      466
# F du Plessis    422
# Name: count, dtype: int64

# %%
df_four=four["batter"].value_counts().head(10)
df_four.sort_values(ascending=False).plot(kind="bar",figsize=(5,2))
# Out:
# <Axes: xlabel='batter'>

# %% [markdown]
# **Who hit most number of 3runs in IPL history**

# %%
three=df3[df3["batsman_runs"]==3]
three["batter"].value_counts().head(10)
# Out:
# batter
# DA Warner         24
# S Dhawan          23
# V Kohli           21
# AM Rahane         19
# F du Plessis      18
# AB de Villiers    17
# M Vijay           17
# G Gambhir         15
# MS Dhoni          15
# RV Uthappa        15
# Name: count, dtype: int64

# %% [markdown]
# **Who hit most number of 2runs in IPL history**

# %%
two=df3[df3["batsman_runs"]==2]
two["batter"].value_counts().head(10)
# Out:
# batter
# V Kohli           445
# DA Warner         370
# MS Dhoni          340
# S Dhawan          299
# SK Raina          271
# AB de Villiers    268
# RG Sharma         263
# KD Karthik        258
# AM Rahane         257
# G Gambhir         249
# Name: count, dtype: int64

# %% [markdown]
# **Who took most number of singles in IPL history**

# %%
one=df3[df3["batsman_runs"]==1]
one["batter"].value_counts().head(10)
# Out:
# batter
# V Kohli       2591
# S Dhawan      2102
# RG Sharma     1996
# SK Raina      1708
# DA Warner     1682
# MS Dhoni      1554
# AM Rahane     1537
# AT Rayudu     1495
# KD Karthik    1464
# KL Rahul      1464
# Name: count, dtype: int64

# %% [markdown]
# **Can you just tell me the Batsman name who hit the most 6 in Chinnaswamy Stadium**

# %%
Chinnaswamy=df3.groupby("venue").get_group("M Chinnaswamy Stadium")
Chinnaswamy[Chinnaswamy["batsman_runs"]==6]["batter"].value_counts().head(10)
# Out:
# batter
# CH Gayle          126
# AB de Villiers     82
# V Kohli            82
# Yuvraj Singh       23
# DA Warner          19
# RV Uthappa         19
# MS Dhoni           18
# MA Agarwal         16
# BB McCullum        15
# YK Pathan          14
# Name: count, dtype: int64

# %% [markdown]
# **Can you just tell me the Batsman name who hit the most 4 in Chinnaswamy Stadium**

# %%
Chinnaswamy=df3.groupby("venue").get_group("M Chinnaswamy Stadium")
Chinnaswamy[Chinnaswamy["batsman_runs"]==4]["batter"].value_counts().head(10)
# Out:
# batter
# V Kohli           165
# CH Gayle          116
# AB de Villiers    110
# JH Kallis          47
# TM Dilshan         40
# G Gambhir          36
# DA Warner          30
# RV Uthappa         30
# R Dravid           30
# AM Rahane          30
# Name: count, dtype: int64

# %% [markdown]
# **Can you just tell me the Batsman name who hit the most 6 in Wankhede Stadium**

# %%
Wankhede=df3.groupby("venue").get_group("Wankhede Stadium")
Wankhede[Wankhede["batsman_runs"]==4]["batter"].value_counts().head(10)
# Out:
# batter
# RG Sharma          156
# SR Tendulkar        94
# KA Pollard          78
# AT Rayudu           76
# PA Patel            70
# SA Yadav            62
# KD Karthik          62
# SK Raina            45
# JC Buttler          39
# Harbhajan Singh     38
# Name: count, dtype: int64

# %% [markdown]
# **Can you just tell me the Batsman name who hit the most 4 in Wankhede Stadium**

# %%
Wankhede=df3.groupby("venue").get_group("Wankhede Stadium")
Wankhede[Wankhede["batsman_runs"]==4]["batter"].value_counts().head(10)
# Out:
# batter
# RG Sharma          156
# SR Tendulkar        94
# KA Pollard          78
# AT Rayudu           76
# PA Patel            70
# SA Yadav            62
# KD Karthik          62
# SK Raina            45
# JC Buttler          39
# Harbhajan Singh     38
# Name: count, dtype: int64
